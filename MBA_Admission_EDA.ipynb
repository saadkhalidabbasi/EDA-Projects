# %% [markdown]
# <a href="https://colab.research.google.com/github/saadkhalidabbasi/EDA-Projects/blob/main/MBA_Admission_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import warnings
warnings.filterwarnings('ignore')

# %%
# Loading Dataset
df = pd.read_csv('MBA.csv')
df.head()
# Out:
#    application_id  gender  international   gpa       major      race   gmat  \
# 0               1  Female          False  3.30    Business     Asian  620.0
# 1               2    Male          False  3.28  Humanities     Black  680.0
# 2               3  Female           True  3.30    Business       NaN  710.0
# 3               4    Male          False  3.47        STEM     Black  690.0
# 4               5    Male          False  3.35        STEM  Hispanic  590.0
#
#    work_exp          work_industry admission
# 0       3.0     Financial Services     Admit
# 1       5.0  Investment Management       NaN
# 2       5.0             Technology     Admit
# 3       6.0             Technology       NaN
# 4       5.0             Consulting       NaN

# %%
df.tail()
# Out:
#       application_id  gender  international   gpa     major      race   gmat  \
# 6189            6190    Male          False  3.49  Business     White  640.0
# 6190            6191    Male          False  3.18      STEM     Black  670.0
# 6191            6192  Female           True  3.22  Business       NaN  680.0
# 6192            6193    Male           True  3.36  Business       NaN  590.0
# 6193            6194    Male          False  3.23      STEM  Hispanic  650.0
#
#       work_exp work_industry admission
# 6189       5.0         Other       NaN
# 6190       4.0    Consulting       NaN
# 6191       5.0   Health Care     Admit
# 6192       5.0         Other       NaN
# 6193       4.0    Consulting       NaN

# %%
df.shape
# Out:
# (6194, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6194 entries, 0 to 6193
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   application_id  6194 non-null   int64
#  1   gender          6194 non-null   object
#  2   international   6194 non-null   bool
#  3   gpa             6194 non-null   float64
#  4   major           6194 non-null   object
#  5   race            4352 non-null   object
#  6   gmat            6194 non-null   float64
#  7   work_exp        6194 non-null   float64
#  8   work_industry   6194 non-null   object
#  9   admission       1000 non-null   object
# dtypes: bool(1), float64(3), int64(1), object(5)
# memory usage: 441.7+ KB

# %%
df.describe()
# Out:
#        application_id          gpa         gmat     work_exp
# count     6194.000000  6194.000000  6194.000000  6194.000000
# mean      3097.500000     3.250714   651.092993     5.016952
# std       1788.198115     0.151541    49.294883     1.032432
# min          1.000000     2.650000   570.000000     1.000000
# 25%       1549.250000     3.150000   610.000000     4.000000
# 50%       3097.500000     3.250000   650.000000     5.000000
# 75%       4645.750000     3.350000   680.000000     6.000000
# max       6194.000000     3.770000   780.000000     9.000000

# %%
df.isnull().sum()/len(df)*100
# Out:
# application_id     0.000000
# gender             0.000000
# international      0.000000
# gpa                0.000000
# major              0.000000
# race              29.738457
# gmat               0.000000
# work_exp           0.000000
# work_industry      0.000000
# admission         83.855344
# dtype: float64

# %% [markdown]
# ### **Adjusting Missing Values**

# %%
df["race"]=df['race'].fillna(df['race'].mode()[0])

# %%
df.isnull().sum()/len(df)*100
# Out:
# application_id     0.000000
# gender             0.000000
# international      0.000000
# gpa                0.000000
# major              0.000000
# race               0.000000
# gmat               0.000000
# work_exp           0.000000
# work_industry      0.000000
# admission         83.855344
# dtype: float64

# %%
df["admission"]=df['admission'].fillna(df['admission'].mode()[0])

# %%
df.head()
# Out:
#    application_id  gender  international   gpa       major      race   gmat  \
# 0               1  Female          False  3.30    Business     Asian  620.0
# 1               2    Male          False  3.28  Humanities     Black  680.0
# 2               3  Female           True  3.30    Business     White  710.0
# 3               4    Male          False  3.47        STEM     Black  690.0
# 4               5    Male          False  3.35        STEM  Hispanic  590.0
#
#    work_exp          work_industry admission
# 0       3.0     Financial Services     Admit
# 1       5.0  Investment Management     Admit
# 2       5.0             Technology     Admit
# 3       6.0             Technology     Admit
# 4       5.0             Consulting     Admit

# %% [markdown]
# ### **Visualizing the DataSet**

# %%
sns.countplot(df,x="gender")
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %%
sns.countplot(df,x="international")
# Out:
# <Axes: xlabel='international', ylabel='count'>

# %%
# Count plot in plotly
fig = px.histogram(df, x="race",title="Race Distribution in Dataset",)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig=px.pie(df,names='major',title='Major Distribution in Dataset')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df.head()
# Out:
#    application_id  gender  international   gpa       major      race   gmat  \
# 0               1  Female          False  3.30    Business     Asian  620.0
# 1               2    Male          False  3.28  Humanities     Black  680.0
# 2               3  Female           True  3.30    Business     White  710.0
# 3               4    Male          False  3.47        STEM     Black  690.0
# 4               5    Male          False  3.35        STEM  Hispanic  590.0
#
#    work_exp          work_industry admission
# 0       3.0     Financial Services     Admit
# 1       5.0  Investment Management     Admit
# 2       5.0             Technology     Admit
# 3       6.0             Technology     Admit
# 4       5.0             Consulting     Admit

# %%
sns.histplot(df,x="gpa",)
# Out:
# <Axes: xlabel='gpa', ylabel='Count'>

# %%
sns.histplot(df,x="work_exp")
# Out:
# <Axes: xlabel='work_exp', ylabel='Count'>

# %%
sns.lineplot(df,x="gpa",y="work_exp")
# Out:
# <Axes: xlabel='gpa', ylabel='work_exp'>

# %%
fig=px.pie(df,names="work_industry",title="Work Industry Distribution in Dataset")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig=px.scatter(df,x="gpa",y="admission",title="GPA vs Admission")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# gpa bs gmat score
fig=px.scatter(df,x="gpa",y="gmat",title="GPA vs GMAT Score")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
sns.barplot(df,x="race",y="gmat")
# Out:
# <Axes: xlabel='race', ylabel='gmat'>

# %%
df.head()
# Out:
#    application_id  gender  international   gpa       major      race   gmat  \
# 0               1  Female          False  3.30    Business     Asian  620.0
# 1               2    Male          False  3.28  Humanities     Black  680.0
# 2               3  Female           True  3.30    Business     White  710.0
# 3               4    Male          False  3.47        STEM     Black  690.0
# 4               5    Male          False  3.35        STEM  Hispanic  590.0
#
#    work_exp          work_industry admission
# 0       3.0     Financial Services     Admit
# 1       5.0  Investment Management     Admit
# 2       5.0             Technology     Admit
# 3       6.0             Technology     Admit
# 4       5.0             Consulting     Admit

# %%
df.groupby('gender').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)
